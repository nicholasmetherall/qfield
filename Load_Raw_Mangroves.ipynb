# %%
import json

import odc.geo
from dep_tools.azure import get_container_client, list_blob_container
from odc.stac import load
from pystac import Item

# %%
client = get_container_client()
docs = list_blob_container(client, prefix='dep_s2_mangroves/0-0-4/', suffix='.json')

# %%
docs = [d for d in docs]
print(f"Found {len(docs)} documents")
# Out:
# Found 23 documents

# %%
base_url = "https://deppcpublicstorage.blob.core.windows.net/output/{key}"
items = [Item.from_file(base_url.format(key=d)) for d in docs]

# %%
data = load(items, chunks={})
data
# Out:
# <xarray.Dataset>
# Dimensions:      (y: 35452, x: 51176, time: 1)
# Coordinates:
#   * y            (y) float64 -1.808e+06 -1.808e+06 ... -2.163e+06 -2.163e+06
#   * x            (x) float64 2.998e+06 2.998e+06 ... 3.509e+06 3.509e+06
#     spatial_ref  int32 3832
#   * time         (time) datetime64[ns] 2021-01-01
# Data variables:
#     ndvi         (time, y, x) float32 dask.array<chunksize=(1, 35452, 51176), meta=np.ndarray>
#     mangroves    (time, y, x) float32 dask.array<chunksize=(1, 35452, 51176), meta=np.ndarray>

# %%
data.isel(time=0).mangroves.odc.write_cog("mangroves.tif", nodata=-32767)
# Out:
# PosixPath('mangroves.tif')
